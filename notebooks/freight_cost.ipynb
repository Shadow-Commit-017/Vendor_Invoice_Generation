# %%
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt

# %%
conn = sqlite3.connect("C:/Users/Divyanshu/ML_PROJECT/data/inventory.db")

tables = pd.read_sql_query(
    "SELECT name FROM sqlite_master WHERE type='table'",
    conn
)

# %%
tables
# Out:
#               name
# 0        purchases
# 1  purchase_prices
# 2   vendor_invoice
# 3  begin_inventory
# 4    end_inventory

# %%
for table in tables['name']:
    print("Table name:", table)
    df = pd.read_sql_query(f"SELECT * from {table} limit 5",conn)
    display(df)
# Out:
# Table name: purchases
#            InventoryId  Store  Brand                   Description   Size  \
# 0    69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno  750mL
# 1     30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 3  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 4    76_DONCASTER_2034     76   2034     Glendalough Double Barrel  750mL
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0           105  ALTAMAR BRANDS LLC               8124  2023-12-21
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 2          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 3          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 4           388  ATLANTIC IMPORTING COMPANY       8169  2023-12-24
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# ...

# %%
vendor_df = pd.read_sql_query("SELECT * FROM vendor_invoice",conn)
vendor_df.head()
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2024-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 2           388  ATLANTIC IMPORTING COMPANY   2024-01-09      8169
# 3           480  BACARDI USA INC              2024-01-12      8106
# 4           516  BANFI PRODUCTS CORP          2024-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval
# 0  2023-12-21  2024-02-16         6     214.26     3.47     None
# 1  2023-12-22  2024-02-21        15     140.55     8.57     None
# 2  2023-12-24  2024-02-16         5     106.60     4.61     None
# 3  2023-12-20  2024-02-05     10100  137483.78  2935.20     None
# 4  2023-12-24  2024-02-12      1935   15527.25   429.20     None

# %%
vendor_df[["Quantity","Dollars","Freight"]].corr()
# Out:
#           Quantity   Dollars   Freight
# Quantity  1.000000  0.963831  0.946550
# Dollars   0.963831  1.000000  0.985141
# Freight   0.946550  0.985141  1.000000

# %%
correlation_data = vendor_df[['Quantity', 'Freight', 'Dollars']]

# Plotting the Heatmap
plt.figure(figsize=(4, 2))
sns.heatmap(correlation_data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Plotting Quantity vs Freight Cost
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.scatter(vendor_df['Quantity'], vendor_df['Freight'], color='#f57a55')
plt.xlabel('Quantity')
plt.ylabel('Freight Cost')
plt.title('Quantity vs Freight')

# Plotting Dollars vs Freight Cost
plt.subplot(1, 2, 2)
plt.scatter(vendor_df['Dollars'], vendor_df['Freight'], color='#7f1e5a')
plt.xlabel('Dollars')
plt.ylabel('Freight Cost')
plt.title('Dollars vs Freight')

plt.tight_layout()
plt.show()

# %%
vendor_df["fright_per_unit"] = vendor_df["Freight"]/vendor_df["Quantity"]

# %%
vendor_df.head()
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2024-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 2           388  ATLANTIC IMPORTING COMPANY   2024-01-09      8169
# 3           480  BACARDI USA INC              2024-01-12      8106
# 4           516  BANFI PRODUCTS CORP          2024-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval  \
# 0  2023-12-21  2024-02-16         6     214.26     3.47     None
# 1  2023-12-22  2024-02-21        15     140.55     8.57     None
# 2  2023-12-24  2024-02-16         5     106.60     4.61     None
# 3  2023-12-20  2024-02-05     10100  137483.78  2935.20     None
# 4  2023-12-24  2024-02-12      1935   15527.25   429.20     None
#
#    fright_per_unit
# 0         0.578333
# 1         0.571333
# 2         0.922000
# 3         0.290614
# 4         0.221809

# %%
low_quantity = vendor_df["Quantity"].quantile(0.25)
high_quantity = vendor_df["Quantity"].quantile(0.75)

# %%
vendor_df.loc[vendor_df['Quantity'] < low_quantity, 'fright_per_unit'].mean()
# Out:
# 0.09489854253138316

# %%
vendor_df.loc[vendor_df['Quantity'] > high_quantity, 'fright_per_unit'].mean()
# Out:
# 0.049077654690759046

# %%
X = vendor_df[["Quantity", "Dollars"]]
y = vendor_df["Freight"]

# %%
vendor_df.describe().round()
# Out:
#        VendorNumber  PONumber  Quantity    Dollars  Freight  fright_per_unit
# count        5543.0    5543.0    5543.0     5543.0   5543.0           5543.0
# mean        20663.0   10889.0    6059.0    58073.0    296.0              0.0
# std         34582.0    1601.0   14453.0   140234.0    714.0              0.0
# min             2.0    8106.0       1.0        4.0      0.0              0.0
# 25%          3089.0    9504.0      83.0      968.0      5.0              0.0
# 50%          7240.0   10890.0     423.0     4765.0     25.0              0.0
# 75%         10754.0   12276.0    5100.0    44587.0    230.0              0.0
# max        201359.0   13661.0  141660.0  1660436.0   8468.0              3.0

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.20, random_state = 42
)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
model1 = LinearRegression()
model1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model2 = DecisionTreeRegressor(max_depth = 4, random_state = 42)
model2.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=4, random_state=42)

# %%
model3 = RandomForestRegressor(max_depth = 4,random_state = 42)
model3.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=4, random_state=42)

# %%
def evaluate_models(models, X_test, y_test):
    results = []
    
    for name, model in models.items():
        pred = model.predict(X_test)
        
        mae = mean_absolute_error(y_test, pred)
        mse = mean_squared_error(y_test, pred)
        r2 = r2_score(y_test, pred)
        
        results.append({
            'Model': name,
            'MAE': mae,
            'MSE': mse,
            'R2 Score': r2
        })
    
    return pd.DataFrame(results)

my_models = {
    "Linear Regression": model1,
    "Decision Tree": model2,
    "Random Forest": model3
}

performance_df = evaluate_models(my_models, X_test, y_test)
performance_df
# Out:
#                Model        MAE           MSE  R2 Score
# 0  Linear Regression  24.459181  15482.522465  0.970020
# 1      Decision Tree  38.116550  19112.513745  0.962991
# 2      Random Forest  30.274521  17063.345976  0.966959

# %%
plt.scatter(y_test, model1.predict(X_test))
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.show()
